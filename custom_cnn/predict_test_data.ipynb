# %%
import tensorflow as tf
import os
import numpy as np
from PIL import Image
import pandas as pd
# Out:
# /Library/Python/2.7/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.23) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
test_dir = 'dataset/processed/test'

n_files = len(os.listdir(test_dir))
n_files
# Out:
# 10357

# %%
labels_file = 'dataset/labels.csv'


labels_df = pd.read_csv(labels_file)
labels_df = labels_df.sample(frac=1).reset_index(drop=True)


g = labels_df['breed'].value_counts()
classes = list(g.keys())
classes
# Out:
# ['scottish_deerhound',
#  'maltese_dog',
#  'afghan_hound',
#  'entlebucher',
#  'bernese_mountain_dog',
#  'shih-tzu',
#  'pomeranian',
#  'great_pyrenees',
#  'basenji',
#  'samoyed',
#  'tibetan_terrier',
#  'airedale',
#  'leonberg',
#  'cairn',
#  'beagle',
#  'japanese_spaniel',
#  'blenheim_spaniel',
#  'australian_terrier',
#  'miniature_pinscher',
#  'irish_wolfhound',
#  'lakeland_terrier',
#  'saluki',
#  'papillon',
#  'norwegian_elkhound',
#  'whippet',
#  'siberian_husky',
#  'pug',
#  'chow',
#  'italian_greyhound',
#  'pembroke',
#  'newfoundland',
#  'border_terrier',
#  'ibizan_hound',
#  'silky_terrier',
#  'lhasa',
#  'bedlington_terrier',
#  'dandie_dinmont',
#  'irish_setter',
#  'sealyham_terrier',
#  'rhodesian_ridgeback',
#  'collie',
#  'old_english_sheepdog',
#  'boston_bull',
#  'schipperke',
#  'english_foxhound',
#  'bouvier_des_flandres',
#  'kelpie',
#  'african_hunting_dog',
#  'bloodhound',
#  'bluetick',
#  'weimaraner',
#  'saint_bernard',
#  'labrador_retriever',
#  'english_setter',
#  'norfolk_terrier',
#  'chesapeake_bay_retriever',
#  'groenendael',
#  'irish_terrier',
#  'greater_swiss_mountain_dog',
#  'wire-haired_fox_terrier',
#  'basset',
#  'kerry_blue_terrier',
#  'yorkshire_terrier',
#  'scotch_terrier',
#  'keeshond',
#  'gordon_setter',
#  'west_highland_white_terrier',
#  'malamute',
#  'affenpinscher',
#  'dingo',
#  'mexican_hairless',
#  'clumber',
#  'toy_poodle',
#  'welsh_springer_spaniel',
#  'toy_terrier',
#  'staffordshire_bullterrier',
#  'miniature_poodle',
#  'standard_poodle',
#  'sussex_spaniel',
#  'norwich_terrier',
#  'appenzeller',
#  'irish_water_spaniel',
#  'miniature_schnauzer',
#  'black-and-tan_coonhound',
#  'dhole',
#  'cardigan',
#  'rottweiler',
#  'shetland_sheepdog',
#  'german_short-haired_pointer',
#  'borzoi',
#  'pekinese',
#  'bull_mastiff',
#  'english_springer',
#  'great_dane',
#  'boxer',
#  'cocker_spaniel',
#  'doberman',
#  'american_staffordshire_terrier',
#  'malinois',
#  'brittany_spaniel',
#  'curly-coated_retriever',
#  'border_collie',
#  'flat-coated_retriever',
#  'redbone',
#  'standard_schnauzer',
#  'kuvasz',
#  'soft-coated_wheaten_terrier',
#  'chihuahua',
#  'french_bulldog',
#  'vizsla',
#  'german_shepherd',
#  'tibetan_mastiff',
#  'walker_hound',
#  'otterhound',
#  'giant_schnauzer',
#  'brabancon_griffon',
#  'komondor',
#  'golden_retriever',
#  'briard',
#  'eskimo_dog']

# %%
def get_image(filename):
    img = Image.open(filename)
    return np.asarray(img, dtype="int32").flatten() / 255.0

# %%
seek_pointer = 0
def get_imgs_and_filenames_batch(size=64):
    global seek_pointer
    continue_flag = True
    start = seek_pointer
    end = seek_pointer = start + size
    imgs = []
    filenames = []
    
    if end >= n_files:
        end = seek_pointer = n_files
        continue_flag = False
    for file_ in os.listdir(test_dir)[start:end]:
        img = get_image(os.path.join(test_dir, file_))
        imgs.append(img)
        filenames.append(file_.split(".")[0])
    print "processed {} out of {}".format(seek_pointer, n_files)
    return imgs, filenames, continue_flag

# %%
checkpoint_prefix = 'dataset/tmp/checkpoint-rmsprop/'
graph = tf.get_default_graph()
checkpoint_file = tf.train.latest_checkpoint(checkpoint_prefix)
saver = tf.train.import_meta_graph("{}.meta".format(checkpoint_file))

# %%
seek_pointer = 0
submission_df = pd.read_csv('dataset/submission.csv')
submission_df = submission_df.drop(index=range(10357))
submission_df

with tf.Session(graph=graph) as sess:
    saver.restore(sess, checkpoint_file)
    
    x = graph.get_tensor_by_name("x:0")
    logits_op = graph.get_tensor_by_name("logits/BiasAdd:0")
    
    loop_flag = True
    c = 0
    while loop_flag:
        imgs, filenames, loop_flag = get_imgs_and_filenames_batch()
        logits_ = sess.run(tf.nn.softmax(logits_op), feed_dict={x: imgs})
        new_df = pd.DataFrame(logits_, columns=classes)
        new_df['id'] = filenames
        submission_df = submission_df.append(new_df, ignore_index=True)
        c += 1
# Out:
# INFO:tensorflow:Restoring parameters from dataset/tmp/checkpoint-rmsprop/-2460
# processed 64 out of 10357
# processed 128 out of 10357
# processed 192 out of 10357
# processed 256 out of 10357
# processed 320 out of 10357
# processed 384 out of 10357
# processed 448 out of 10357
# processed 512 out of 10357
# processed 576 out of 10357
# processed 640 out of 10357
# processed 704 out of 10357
# processed 768 out of 10357
# processed 832 out of 10357
# processed 896 out of 10357
# processed 960 out of 10357
# processed 1024 out of 10357
# processed 1088 out of 10357
# processed 1152 out of 10357
# processed 1216 out of 10357
# processed 1280 out of 10357
# processed 1344 out of 10357
# processed 1408 out of 10357
# processed 1472 out of 10357
# processed 1536 out of 10357
# processed 1600 out of 10357
# processed 1664 out of 10357
# processed 1728 out of 10357
# processed 1792 out of 10357
# processed 1856 out of 10357
# processed 1920 out of 10357
# processed 1984 out of 10357
# processed 2048 out of 10357
# processed 2112 out of 10357
# processed 2176 out of 10357
# processed 2240 out of 10357
# processed 2304 out of 10357
# processed 2368 out of 10357
# processed 2432 out of 10357
# processed 2496 out of 10357
# processed 2560 out of 10357
# processed 2624 out of 10357
# processed 2688 out of 10357
# processed 2752 out of 10357
# processed 2816 out of 10357
# processed 2880 out of 10357
# processed 2944 out of 10357
# processed 3008 out of 10357
# processed 3072 out of 10357
# processed 3136 out of 10357
# processed 3200 out of 10357
# processed 3264 out of 10357
# processed 3328 out of 10357
# processed 3392 out of 10357
# processed 3456 out of 10357
# processed 3520 out of 10357
# processed 3584 out of 10357
# processed 3648 out of 10357
# processed 3712 out of 10357
# processed 3776 out of 10357
# processed 3840 out of 10357
# processed 3904 out of 10357
# processed 3968 out of 10357
# processed 4032 out of 10357
# processed 4096 out of 10357
# processed 4160 out of 10357
# processed 4224 out of 10357
# processed 4288 out of 10357
# processed 4352 out of 10357
# processed 4416 out of 10357
# processed 4480 out of 10357
# processed 4544 out of 10357
# processed 4608 out of 10357
# processed 4672 out of 10357
# processed 4736 out of 10357
# processed 4800 out of 10357
# processed 4864 out of 10357
# processed 4928 out of 10357
# processed 4992 out of 10357
# processed 5056 out of 10357
# processed 5120 out of 10357
# processed 5184 out of 10357
# processed 5248 out of 10357
# processed 5312 out of 10357
# processed 5376 out of 10357
# processed 5440 out of 10357
# processed 5504 out of 10357
# processed 5568 out of 10357
# processed 5632 out of 10357
# processed 5696 out of 10357
# processed 5760 out of 10357
# processed 5824 out of 10357
# processed 5888 out of 10357
# processed 5952 out of 10357
# processed 6016 out of 10357
# processed 6080 out of 10357
# processed 6144 out of 10357
# processed 6208 out of 10357
# processed 6272 out of 10357
# processed 6336 out of 10357
# processed 6400 out of 10357
# processed 6464 out of 10357
# processed 6528 out of 10357
# processed 6592 out of 10357
# processed 6656 out of 10357
# processed 6720 out of 10357
# processed 6784 out of 10357
# processed 6848 out of 10357
# processed 6912 out of 10357
# processed 6976 out of 10357
# processed 7040 out of 10357
# processed 7104 out of 10357
# processed 7168 out of 10357
# processed 7232 out of 10357
# processed 7296 out of 10357
# processed 7360 out of 10357
# processed 7424 out of 10357
# processed 7488 out of 10357
# processed 7552 out of 10357
# processed 7616 out of 10357
# processed 7680 out of 10357
# processed 7744 out of 10357
# processed 7808 out of 10357
# processed 7872 out of 10357
# processed 7936 out of 10357
# processed 8000 out of 10357
# processed 8064 out of 10357
# processed 8128 out of 10357
# processed 8192 out of 10357
# processed 8256 out of 10357
# processed 8320 out of 10357
# processed 8384 out of 10357
# processed 8448 out of 10357
# processed 8512 out of 10357
# processed 8576 out of 10357
# processed 8640 out of 10357
# processed 8704 out of 10357
# processed 8768 out of 10357
# processed 8832 out of 10357
# processed 8896 out of 10357
# processed 8960 out of 10357
# processed 9024 out of 10357
# processed 9088 out of 10357
# processed 9152 out of 10357
# processed 9216 out of 10357
# processed 9280 out of 10357
# processed 9344 out of 10357
# processed 9408 out of 10357
# processed 9472 out of 10357
# processed 9536 out of 10357
# processed 9600 out of 10357
# processed 9664 out of 10357
# processed 9728 out of 10357
# processed 9792 out of 10357
# processed 9856 out of 10357
# processed 9920 out of 10357
# processed 9984 out of 10357
# processed 10048 out of 10357
# processed 10112 out of 10357
# processed 10176 out of 10357
# processed 10240 out of 10357
# processed 10304 out of 10357
# processed 10357 out of 10357

# %%
submission_df.to_csv('dataset/submission_4.csv', index=False)

# %%
len(submission_df)
# Out:
# 10357
